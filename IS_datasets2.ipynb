# %%
import pandas as pd

# %% [markdown]
# # Healthcare-Diabetes.csv (https://www.kaggle.com/datasets/nanditapore/healthcare-diabetes)

# %%
dataset1 = pd.read_csv("/content/Healthcare-Diabetes.csv")
print("rows columns\n", dataset1.shape)
# Out:
# rows columns
#  (2768, 10)

# %%
dataset1.head(10)
# Out:
#    Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0   1            6      148             72             35        0  33.6
# 1   2            1       85             66             29        0  26.6
# 2   3            8      183             64              0        0  23.3
# 3   4            1       89             66             23       94  28.1
# 4   5            0      137             40             35      168  43.1
# 5   6            5      116             74              0        0  25.6
# 6   7            3       78             50             32       88  31.0
# 7   8           10      115              0              0        0  35.3
# 8   9            2      197             70             45      543  30.5
# 9  10            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# ...

# %% [markdown]
# # diabetes_data.csv (https://www.kaggle.com/datasets/rabieelkharoua/diabetes-health-dataset-analysis)

# %%
dataset2 = pd.read_csv("/content/diabetes_data.csv")
print("rows columns\n", dataset1.shape)
# Out:
# rows columns
#  (2768, 10)

# %%
dataset2.head(10)
# Out:
#    PatientID  Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel  \
# 0       6000   44       0          1                    2               1
# 1       6001   51       1          0                    1               2
# 2       6002   89       1          0                    1               3
# 3       6003   21       1          1                    1               2
# 4       6004   27       1          0                    1               3
# 5       6005   65       0          0                    0               0
# 6       6006   61       1          2                    1               3
# 7       6007   74       1          3                    0               3
# 8       6008   54       0          0                    1               2
# 9       6009   82       1          0                    1               1
#
#          BMI  Smoking  AlcoholConsumption  PhysicalActivity  ...  \
# 0  32.985284        1            4.499365          2.443385  ...
# ...
